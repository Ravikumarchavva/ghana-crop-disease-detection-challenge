# %% [markdown]
# # Setting Up

# %%
import os
import sys
sys.path.append(os.path.join(os.getcwd(), '..'))
from configs import paths_helper

# Set up directoris for training a yolo model

# Images directories
from pathlib import Path
DATA_DIR = Path(paths_helper.DATA_DIR)
DATASET_DIR = DATA_DIR
IMAGES_DIR = DATASET_DIR / 'images'
TRAIN_IMAGES_DIR = IMAGES_DIR / 'train'
VAL_IMAGES_DIR = IMAGES_DIR / 'val'
TEST_IMAGES_DIR = IMAGES_DIR / 'test'

# Labels directories
LABELS_DIR = DATASET_DIR / 'labels'
TRAIN_LABELS_DIR = LABELS_DIR / 'train'
VAL_LABELS_DIR = LABELS_DIR / 'val'
TEST_LABELS_DIR = LABELS_DIR / 'test'

# %% [markdown]
# # Reading Data

# %%
import pandas as pd
# Load train and test files
train = pd.read_csv(DATA_DIR / 'Train.csv')
test = pd.read_csv(DATA_DIR / 'Test.csv')
ss = pd.read_csv(DATA_DIR / 'SampleSubmission.csv')

# Add an image_path column
train['image_path'] = [Path('images/' + x) for x in train.Image_ID]
test['image_path'] = [Path('images/' + x) for x in test.Image_ID]

# Map str classes to ints (label encoding targets)
class_mapper = {x:y for x,y in zip(sorted(train['class'].unique().tolist()), range(train['class'].nunique()))}
train['class_id'] = train['class'].map(class_mapper)

# Preview the head of the train set
train.head()
# Out:
#         Image_ID  confidence                  class         ymin        xmin  \
# 0  id_11543h.jpg         1.0  Pepper_Bacterial_Spot   194.649671  328.803454
# 1  id_11543h.jpg         1.0  Pepper_Bacterial_Spot   149.632401  256.768914
# 2  id_11543h.jpg         1.0  Pepper_Bacterial_Spot   234.046875  327.138158
# 3  id_11543h.jpg         1.0  Pepper_Bacterial_Spot   221.277138  340.411184
# 4  id_11ee1c.jpg         1.0        Pepper_Fusarium  2000.563598  989.588908
#
#           ymax         xmax            image_path  class_id
# 0   208.107730   341.967928  images\id_11543h.jpg         5
# 1   162.910362   266.195724  images\id_11543h.jpg         5
# 2   252.712993   338.876645  images\id_11543h.jpg         5
# 3   238.593750   354.651316  images\id_11543h.jpg         5
# 4  2184.252196  1401.748952  images\id_11ee1c.jpg         8

# %%
test.head()
# Out:
#         Image_ID  confidence  class  ymin  xmin  ymax  xmax  \
# 0  id_128pxx.jpg         NaN    NaN   NaN   NaN   NaN   NaN
# 1  id_12jbci.jpg         NaN    NaN   NaN   NaN   NaN   NaN
# 2  id_143s4o.jpg         NaN    NaN   NaN   NaN   NaN   NaN
# 3  id_14tfmb.jpg         NaN    NaN   NaN   NaN   NaN   NaN
# 4  id_14tw4o.jpg         NaN    NaN   NaN   NaN   NaN   NaN
#
#              image_path
# 0  images\id_128pxx.jpg
# 1  images\id_12jbci.jpg
# 2  images\id_143s4o.jpg
# 3  images\id_14tfmb.jpg
# 4  images\id_14tw4o.jpg

# %%
ss.head()
# Out:
#         Image_ID                      class  confidence  ymin  xmin  ymax  \
# 0  id_128pxx.jpg  Corn_Cercospora_Leaf_Spot         0.5   100   100   100
# 1  id_128pxx.jpg           Corn_Common_Rust         0.5   100   100   100
# 2  id_128pxx.jpg               Corn_Healthy         0.5   100   100   100
# 3  id_128pxx.jpg  Corn_Northern_Leaf_Blight         0.5   100   100   100
# 4  id_128pxx.jpg                Corn_Streak         0.5   100   100   100
#
#    xmax
# 0   100
# 1   100
# 2   100
# 3   100
# 4   100

# %% [markdown]
# # Splitting Data

# %%
from sklearn.model_selection import train_test_split
# Split data into training and validation
train_unique_imgs_df = train.drop_duplicates(subset = ['Image_ID'], ignore_index = True)
X_train, X_val = train_test_split(train_unique_imgs_df, test_size = 0.25, stratify=train_unique_imgs_df['class'], random_state=42)

X_train = train[train.Image_ID.isin(X_train.Image_ID)]
X_val = train[train.Image_ID.isin(X_val.Image_ID)]

# Check shapes of training and validation data
X_train.shape, X_val.shape
# Out:
# ((30777, 9), (10252, 9))

# %% [markdown]
# # Target Distribution (Imbalanced)

# %%
# Preview target distribution, seems there a class imbalance that needs to be handled

target_dis = pd.DataFrame(X_train['class'].value_counts(normalize = True))
target_dis['val'] = X_val['class'].value_counts(normalize = True)
target_dis
# Out:
#                            proportion       val
# class
# Corn_Cercospora_Leaf_Spot    0.160444  0.156067
# Tomato_Septoria              0.159047  0.154897
# Tomato_Late_Blight           0.098905  0.085252
# Corn_Streak                  0.077201  0.078424
# Tomato_Healthy               0.069045  0.072864
# Pepper_Septoria              0.051922  0.067987
# Pepper_Leaf_Mosaic           0.051662  0.051014
# Tomato_Early_Blight          0.047763  0.046430
# Pepper_Bacterial_Spot        0.047665  0.046430
# Corn_Common_Rust             0.040290  0.043114
# Pepper_Leaf_Curl             0.037561  0.036481
# Corn_Healthy                 0.037561  0.040480
# Tomato_Fusarium              0.019950  0.026141
# Pepper_Healthy               0.017935  0.017948
# Pepper_Late_Blight           0.014296  0.013168
# Pepper_Leaf_Blight           0.012574  0.011803
# Tomato_Bacterial_Spot        0.011860  0.011607
# Pepper_Cercospora            0.011405  0.011803
# Pepper_Fusarium              0.011340  0.011998
# Tomato_Leaf_Curl             0.011177  0.009071
# Corn_Northern_Leaf_Blight    0.004289  0.002439
# Tomato_Mosaic                0.003314  0.003121
# Pepper_Early_Blight          0.002794  0.001463

# %% [markdown]
# # Creating Directories

# %%
# Check if dirs exist, if they do, remove them, otherwise create them.
# This only needs to run once
import shutil
for DIR in [TRAIN_IMAGES_DIR,VAL_IMAGES_DIR, TEST_IMAGES_DIR, TRAIN_LABELS_DIR,VAL_LABELS_DIR,TEST_LABELS_DIR]:
  if DIR.exists():
    shutil.rmtree(DIR)
  DIR.mkdir(parents=True, exist_ok = True)

# %%
import shutil
from concurrent.futures import ThreadPoolExecutor
from tqdm.asyncio import tqdm
import asyncio
from pathlib import Path
import nest_asyncio

# Create a shared ThreadPoolExecutor
executor = ThreadPoolExecutor()

async def copy_image(img, dest_dir):
    """Copies a single image to the destination directory."""
    await asyncio.to_thread(shutil.copy, img, dest_dir / Path(img).name)

async def copy_images_with_progress(imgs, dest_dir):
    """Copies images with a progress bar asynchronously using ThreadPoolExecutor."""
    with tqdm(total=len(imgs), desc=f"Copying to {dest_dir.name}") as pbar:
        tasks = [copy_image(img, dest_dir) for img in imgs]
        for coro in asyncio.as_completed(tasks):
            await coro  # Wait for each task to complete
            pbar.update()

async def main():
    # Run all the copying tasks concurrently
    await asyncio.gather(
        copy_images_with_progress(X_train.image_path.unique(), TRAIN_IMAGES_DIR),
        copy_images_with_progress(X_val.image_path.unique(), VAL_IMAGES_DIR),
        copy_images_with_progress(test.image_path.unique(), TEST_IMAGES_DIR),
    )

# Allow nested use of asyncio.run()
nest_asyncio.apply()

# Run the main event loop
asyncio.run(main())
# Out:
# Copying to train:   0%|          | 0/3676 [00:00<?, ?it/s]
# Copying to train:   0%|          | 0/3676 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 35
#      32 nest_asyncio.apply()
#      34 # Run the main event loop
# ---> 35 asyncio.run(main())
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\asyncio\futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception
#     202 return self._result
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\asyncio\tasks.py:258, in Task.__step(***failed resolving arguments***)
#     256         result = coro.send(None)
#     257     else:
# --> 258         result = coro.throw(exc)
#     259 except StopIteration as exc:
#     260     if self._must_cancel:
#     261         # Task is cancelled right before coro stops.
#
# Cell In[28], line 25, in main()
#      23 async def main():
#      24     # Run all the copying tasks concurrently
# ---> 25     await asyncio.gather(
#      26         copy_images_with_progress(X_train.image_path.unique(), TRAIN_IMAGES_DIR),
#      27         copy_images_with_progress(X_val.image_path.unique(), VAL_IMAGES_DIR),
#      28         copy_images_with_progress(test.image_path.unique(), TEST_IMAGES_DIR),
#      29     )
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\asyncio\tasks.py:328, in Task.__wakeup(self, future)
#     326 def __wakeup(self, future):
#     327     try:
# --> 328         future.result()
#     329     except BaseException as exc:
#     330         # This may also be a cancellation.
#     331         self.__step(exc)
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\asyncio\tasks.py:256, in Task.__step(***failed resolving arguments***)
#     252 try:
#     253     if exc is None:
#     254         # We use the `send` method directly, because coroutines
#     255         # don't have `__iter__` and `__next__` methods.
# --> 256         result = coro.send(None)
#     257     else:
#     258         result = coro.throw(exc)
#
# Cell In[28], line 20, in copy_images_with_progress(imgs, dest_dir)
#      18 tasks = [copy_image(img, dest_dir) for img in imgs]
#      19 for coro in asyncio.as_completed(tasks):
# ---> 20     await coro  # Wait for each task to complete
#      21     pbar.update()
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\asyncio\tasks.py:611, in as_completed.<locals>._wait_for_one()
#     608 if f is None:
#     609     # Dummy value from _on_timeout().
#     610     raise exceptions.TimeoutError
# --> 611 return f.result()
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\asyncio\futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception
#     202 return self._result
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\asyncio\tasks.py:258, in Task.__step(***failed resolving arguments***)
#     256         result = coro.send(None)
#     257     else:
# --> 258         result = coro.throw(exc)
#     259 except StopIteration as exc:
#     260     if self._must_cancel:
#     261         # Task is cancelled right before coro stops.
#
# Cell In[28], line 13, in copy_image(img, dest_dir)
#      11 async def copy_image(img, dest_dir):
#      12     """Copies a single image to the destination directory."""
# ---> 13     await asyncio.to_thread(shutil.copy, img, dest_dir / Path(img).name)
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\asyncio\threads.py:25, in to_thread(func, *args, **kwargs)
#      23 ctx = contextvars.copy_context()
#      24 func_call = functools.partial(ctx.run, func, *args, **kwargs)
# ---> 25 return await loop.run_in_executor(None, func_call)
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\asyncio\futures.py:284, in Future.__await__(self)
#     282 if not self.done():
#     283     self._asyncio_future_blocking = True
# --> 284     yield self  # This tells Task to wait for completion.
#     285 if not self.done():
#     286     raise RuntimeError("await wasn't used with future")
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\asyncio\tasks.py:328, in Task.__wakeup(self, future)
#     326 def __wakeup(self, future):
#     327     try:
# --> 328         future.result()
#     329     except BaseException as exc:
#     330         # This may also be a cancellation.
#     331         self.__step(exc)
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\asyncio\futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception
#     202 return self._result
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\shutil.py:427, in copy(src, dst, follow_symlinks)
#     425 if os.path.isdir(dst):
#     426     dst = os.path.join(dst, os.path.basename(src))
# --> 427 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     428 copymode(src, dst, follow_symlinks=follow_symlinks)
#     429 return dst
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\shutil.py:264, in copyfile(src, dst, follow_symlinks)
#     262     os.symlink(os.readlink(src), dst)
#     263 else:
# --> 264     with open(src, 'rb') as fsrc:
#     265         try:
#     266             with open(dst, 'wb') as fdst:
#     267                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images\\id_517hum.jpg'
# Copying to val:   0%|          | 0/1226 [00:01<?, ?it/s]
# Copying to test:   0%|          | 0/2101 [00:01<?, ?it/s]

# %%
# Copy train, val and test images to their respective dirs
for img in tqdm(X_train.image_path.unique()):
  shutil.copy(img, TRAIN_IMAGES_DIR / img.parts[-1])

for img in tqdm(X_val.image_path.unique()):
  shutil.copy(img, VAL_IMAGES_DIR / img.parts[-1])

for img in tqdm(test.image_path.unique()):
  shutil.copy(img, TEST_IMAGES_DIR / img.parts[-1])
# Out:
#   0%|          | 0/3676 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 3
#       1 # Copy train, val and test images to their respective dirs
#       2 for img in tqdm(X_train.image_path.unique()):
# ----> 3   shutil.copy(img, TRAIN_IMAGES_DIR / img.parts[-1])
#       5 for img in tqdm(X_val.image_path.unique()):
#       6   shutil.copy(img, VAL_IMAGES_DIR / img.parts[-1])
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\shutil.py:427, in copy(src, dst, follow_symlinks)
#     425 if os.path.isdir(dst):
#     426     dst = os.path.join(dst, os.path.basename(src))
# --> 427 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     428 copymode(src, dst, follow_symlinks=follow_symlinks)
#     429 return dst
#
# File c:\Users\chavv\anaconda\envs\huggingface-torch\lib\shutil.py:264, in copyfile(src, dst, follow_symlinks)
#     262     os.symlink(os.readlink(src), dst)
#     263 else:
# --> 264     with open(src, 'rb') as fsrc:
#     265         try:
#     266             with open(dst, 'wb') as fdst:
#     267                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'images\\id_11543h.jpg'
